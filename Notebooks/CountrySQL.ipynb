# %%
import warnings
warnings.filterwarnings('ignore')
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://millbr02:@localhost/world
# Out:
# 'Connected: millbr02@world'

# %%
# %%sql
#
# select *
# from country
# where region = 'Middle East';
# Out:
# 18 rows affected.
# [('ARE', 'United Arab Emirates', 'Asia', 'Middle East', 83600.0, 1971, 2441000, 74.1, Decimal('37966.00'), Decimal('36846.00'), 'Al-Imarat al-´Arabiya al-Muttahida', 'Emirate Federation', 'Zayid bin Sultan al-Nahayan', 65, 'AE'),
#  ('ARM', 'Armenia', 'Asia', 'Middle East', 29800.0, 1991, 3520000, 66.4, Decimal('1813.00'), Decimal('1627.00'), 'Hajastan', 'Republic', 'Robert Kot\x9aarjan', 126, 'AM'),
#  ('AZE', 'Azerbaijan', 'Asia', 'Middle East', 86600.0, 1991, 7734000, 62.9, Decimal('4127.00'), Decimal('4100.00'), 'Azärbaycan', 'Federal Republic', 'Heydär Äliyev', 144, 'AZ'),
#  ('BHR', 'Bahrain', 'Asia', 'Middle East', 694.0, 1971, 617000, 73.0, Decimal('6366.00'), Decimal('6097.00'), 'Al-Bahrayn', 'Monarchy (Emirate)', 'Hamad ibn Isa al-Khalifa', 149, 'BH'),
#  ('GEO', 'Georgia', 'Asia', 'Middle East', 69700.0, 1991, 4968000, 64.5, Decimal('6064.00'), Decimal('5924.00'), 'Sakartvelo', 'Republic', 'Eduard \x8aevardnadze', 905, 'GE'),
# ...

# %%
# %%sql
#
# select name, region from country where region = 'Middle East';
# Out:
# 18 rows affected.
# [('United Arab Emirates', 'Middle East'),
#  ('Armenia', 'Middle East'),
#  ('Azerbaijan', 'Middle East'),
#  ('Bahrain', 'Middle East'),
#  ('Georgia', 'Middle East'),
#  ('Iraq', 'Middle East'),
#  ('Israel', 'Middle East'),
#  ('Yemen', 'Middle East'),
#  ('Jordan', 'Middle East'),
#  ('Kuwait', 'Middle East'),
#  ('Cyprus', 'Middle East'),
#  ('Lebanon', 'Middle East'),
#  ('Oman', 'Middle East'),
#  ('Qatar', 'Middle East'),
#  ('Saudi Arabia', 'Middle East'),
#  ('Syria', 'Middle East'),
#  ('Turkey', 'Middle East'),
#  ('Palestine', 'Middle East')]

# %% [markdown]
# ### select the distinct forms of government

# %%
# %%sql
#
# select distinct governmentform from country;
# Out:
# 35 rows affected.
# [('Monarchy',),
#  ('Socialistic Republic',),
#  ('Federal Republic',),
#  ('Overseas Department of France',),
#  ('Constitutional Monarchy',),
#  ('Special Administrative Region of China',),
#  ('Part of Denmark',),
#  ('Administrated by the UN',),
#  ('Republic',),
#  ('Islamic Republic',),
#  ('US Territory',),
#  ('Monarchy (Emirate)',),
#  ('Dependent Territory of the US',),
#  ('Co-administrated',),
#  ('Dependent Territory of the UK',),
#  ('Constitutional Monarchy, Federation',),
#  ('Territory of Australia',),
#  ('Nonmetropolitan Territory of France',),
#  ('Nonmetropolitan Territory of The Netherlands',),
#  ('Constitutional Monarchy (Emirate)',),
#  ('Occupied by Marocco',),
#  ('Territorial Collectivity of France',),
#  ('Dependent Territory of Norway',),
#  ('Nonmetropolitan Territory of New Zealand',),
#  ('Monarchy (Sultanate)',),
#  ("People'sRepublic",),
#  ('Parliamentary Coprincipality',),
#  ('Commonwealth of the US',),
# ...

# %% [markdown]
# ### List the country name and gnp of the countries in Southeast Asia with population less than 5 million

# %%
# %%sql
#
# select name, gnp
# from country
# where region = 'Southeast Asia' or population < 5000000
# limit 10;
# Out:
# 10 rows affected.
# [('Netherlands Antilles', Decimal('1941.00')),
#  ('Albania', Decimal('3205.00')),
#  ('American Samoa', Decimal('334.00')),
#  ('Andorra', Decimal('1630.00')),
#  ('Anguilla', Decimal('63.20')),
#  ('Antigua and Barbuda', Decimal('612.00')),
#  ('United Arab Emirates', Decimal('37966.00')),
#  ('Armenia', Decimal('1813.00')),
#  ('Aruba', Decimal('828.00')),
#  ('Bahamas', Decimal('3527.00'))]
